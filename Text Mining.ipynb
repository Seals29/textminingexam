# %% [markdown]
# #NIM: 2540120074
# #Nama: Lionel Riyadi
#
# Link Video Penjelasan: https://binusianorg-my.sharepoint.com/personal/lionel_riyadi_binus_ac_id/_layouts/15/guestaccess.aspx?share=ET92mgsv0ahNoyRUjxBhI7oBr3oobkG-vmnFA8dur66iGg&nav=eyJyZWZlcnJhbEluZm8iOnsicmVmZXJyYWxBcHAiOiJPbmVEcml2ZUZvckJ1c2luZXNzIiwicmVmZXJyYWxBcHBQbGF0Zm9ybSI6IldlYiIsInJlZmVycmFsTW9kZSI6InZpZXciLCJyZWZlcnJhbFZpZXciOiJNeUZpbGVzTGlua0RpcmVjdCJ9fQ&e=8tVTE0

# %%
from google.colab import drive
import pandas as pd
import re

drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
ROOT = '/content/drive/MyDrive/Odd2324/TextMining/UTS/'

# %%
dataset = pd.read_csv(ROOT+'dataset.csv',encoding='latin1')
print(dataset)
# Out:
#                                                 Teks       Media      Label
# 0  nasional/read/Pelatih Chelsea, Mauricio Pochet...      Kompas       Bola
# 1  Laporan Wartawan Tribunnews.com, Aisyah Nursya...  Tribunnews  Kesehatan
# 2  Laporan Wartawan Tribunnews.com, Aisyah Nursya...  Tribunnews  Kesehatan
# 3  Laporan Wartawan Tribunnews.com, Aisyah Nursya...  Tribunnews  Kesehatan
# 4  TEMPO.CO, Jakarta - Copa Interamericana akan k...       Tempo       Bola
# 5  JAKARTA, KOMPAS.com - Kepala Staf Angkatan Dar...      Kompas    Politik
# 6  JAKARTA, KOMPAS.com - Pengadilan Tindak Pidana...      Kompas    Politik
# 7  TEMPO.CO, Jakarta - Hasil sigi lembaga survei ...       Tempo    Politik
# 8  TEMPO.CO, Jakarta - Kepala Badan Pengawas Obat...       Tempo    Politik
# 9  KOMPAS.com - Pemain Panama U17, Martin Krug, t...      Kompas       Bola

# %% [markdown]
# Preprocessing Data
# tahap ini, akan membersihkan teks dari huruf yang tidak sesuai seperti simbol, https://, .com, spasi yang berlebih ataupun \n dan \t.

# %%
def remove_special_characters(text):
    return re.sub(r'[^a-zA-Z0-9\s]', '', text)

def convert_to_lowercase(text):
    return text.lower()
def remove_https(text):
    return text.replace('https://','')
def remove_com(text):
    return text.replace('.com','')
def remove_extra_space(text):
    return re.sub(r'\s+', ' ', text)
def remove_enter_and_tab(text):
    cleaned_text = text.replace('\n', ' ').replace('\t', ' ')
    return cleaned_text

# %% [markdown]
# #STOPWORDS Indonesia
# kemudian tak hanya simbol dan huruf tetapi juga menghilangkan dari huruf stopwords indonesia

# %%
import nltk
from nltk.tokenize import word_tokenize
import string
nltk.download('punkt')

nltk.download('stopwords')
from nltk.corpus import stopwords

stop_words = set(stopwords.words('indonesian'))
print(stop_words)
# Buang Stopwordsnya
array_of_tokenized = []
for i,teks in enumerate(dataset['Teks']):
    final = remove_com(teks)
    final = remove_https(final)
    final = remove_enter_and_tab(final)
    final = remove_special_characters(final)
    final = convert_to_lowercase(final)
    final = remove_extra_space(final)

    tokenized = word_tokenize(final)
    filtered_words = [word for word in tokenized if word.lower() not in stop_words]
    dataset.iat[i, 0] = final
    array_of_tokenized.append(filtered_words)
# Out:
# {'akulah', 'diperlukannya', 'dibuat', 'dekat', 'biasanya', 'berakhir', 'ikut', 'bagaimanakah', 'ditegaskan', 'sebaliknya', 'begitukah', 'bukankah', 'panjang', 'tanya', 'bilakah', 'teringat', 'cukuplah', 'mengenai', 'diinginkan', 'namun', 'dengan', 'dialah', 'sesudahnya', 'inilah', 'meyakini', 'kalian', 'lain', 'ditunjukkan', 'janganlah', 'melihatnya', 'ditanyai', 'menanyai', 'bawah', 'diberikan', 'dimaksudkan', 'pula', 'demikianlah', 'paling', 'didapat', 'secara', 'katakanlah', 'bakal', 'hampir', 'waduh', 'hanya', 'nyaris', 'disampaikan', 'kamulah', 'lanjutnya', 'benar', 'belakangan', 'terjadinya', 'merasa', 'sedikitnya', 'seolah', 'sebisanya', 'keluar', 'setidak-tidaknya', 'diketahui', 'wong', 'berturut', 'bertanya-tanya', 'amatlah', 'segalanya', 'diakhiri', 'serupa', 'kasus', 'andalah', 'sinilah', 'berjumlah', 'terlebih', 'berkehendak', 'benarlah', 'antaranya', 'beberapa', 'enggak', 'setempat', 'sudahlah', 'sudahkah', 'disini', 'datang', 'khususnya', 'siap', 'menghendaki', 'tiba-tiba', 'misal', 'sedikit', 'bahwasanya', 'jadi', 'menanya', 'sebab', 'terlihat', 'dini', 'berkali-kali', 'menggunakan', 'tempat', 'betul', 'semata-mata', 'pun', 'sebaik', 'diungkapkan', 'sela', 'yakin', 'bulan', 'disebutkannya', 'sudah', 'sangatlah', 'saling', 'adapun', 'justru', 'agak', 'menanti', 'menandaskan', 'tidak', 'lalu', 'semasih', 'para', 'buat', 'kita', 'misalkan', 'pantas', 'dimulainya', 'anda', 'diingat', 'ibaratkan', 'diketahuinya', 'ditandaskan', 'misalnya', 'kemungkinan', 'kelamaan', 'mampukah', 'menunjukkan', 'tahun', 'sekurang-kurangnya', 'belum', 'berdatangan', 'masing', 'seterusnya', 'sebagian', 'bagaikan', 'lainnya', 'seingat', 'bagian', 'berakhirlah', 'semasa', 'mengingatkan', 'melihat', 'berapapun', 'lama', 'sampaikan', 'sama', 'bagi', 'ibarat', 'manakala', 'sebagaimana', 'terutama', 'jangankan', 'kelihatan', 'termasuk', 'semampunya', 'terlalu', 'harusnya', 'dimulailah', 'itu', 'merupakan', 'pentingnya', 'sendirian', 'inginkan', 'ujarnya', 'bersama-sama', 'dapat', 'sejauh', 'sebagai', 'sekali', 'pak', 'rupanya', 'tegas', 'menjelaskan', 'nah', 'kitalah', 'ini', 'mau', 'pihak', 'sekadar', 'baik', 'sejak', 'enggaknya', 'walau', 'berupa', 'ungkap', 'semuanya', 'ditunjuknya', 'guna', 'mirip', 'menginginkan', 'entah', 'seperti', 'ibu', 'dijelaskan', 'pertama', 'kalau', 'tetap', 'yang', 'berikut', 'lah', 'setengah', 'mendapatkan', 'suatu', 'berlalu', 'dipunyai', 'sepanjang', 'bisakah', 'akan', 'diakhirinya', 'tahu', 'memang', 'memintakan', 'memperlihatkan', 'berarti', 'sana', 'kecil', 'dalam', 'jelas', 'sedang', 'kalaulah', 'terhadapnya', 'masalahnya', 'sama-sama', 'siapakah', 'kembali', 'masalah', 'sangat', 'lagi', 'yakni', 'persoalan', 'benarkah', 'seluruh', 'daripada', 'satu', 'semua', 'setiba', 'tertuju', 'dilakukan', 'berikutnya', 'dibuatnya', 'beginilah', 'menaiki', 'kapan', 'beginikah', 'semacam', 'lanjut', 'sebutnya', 'entahlah', 'jadinya', 'semisalnya', 'berapalah', 'berapakah', 'kurang', 'sayalah', 'menambahkan', 'sebaiknya', 'terdahulu', 'meyakinkan', 'sekitarnya', 'ucapnya', 'memungkinkan', 'hal', 'diberi', 'agar', 'sekadarnya', 'menantikan', 'menjawab', 'kebetulan', 'dimaksudkannya', 'kan', 'betulkah', 'sampai-sampai', 'selama-lamanya', 'jawab', 'jelaskan', 'dituturkannya', 'mana', 'padahal', 'kamilah', 'nyatanya', 'pasti', 'digunakan', 'menuju', 'sering', 'berujar', 'begitulah', 'malah', 'mampu', 'mengibaratkan', 'ia', 'seharusnya', 'adanya', 'kemudian', 'apalagi', 'berlainan', 'belakang', 'memisalkan', 'kok', 'sendirinya', 'terus', 'apaan', 'menunjuki', 'tandas', 'diperbuat', 'tetapi', 'tadinya', 'mengingat', 'mengatakannya', 'awalnya', 'tanyanya', 'nanti', 'menanyakan', 'hendaknya', 'membuat', 'supaya', 'segera', 'sebenarnya', 'kami', 'sehingga', 'tutur', 'itulah', 'seringnya', 'begitupun', 'mulanya', 'macam', 'ditanyakan', 'dikerjakan', 'padanya', 'tapi', 'rata', 'berkenaan', 'asal', 'setiap', 'seluruhnya', 'semisal', 'dua', 'mengakhiri', 'gunakan', 'semata', 'ditunjuki', 'sampai', 'kepadanya', 'tampaknya', 'selama',  ...
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
for i in array_of_tokenized:
  print(i)
# Out:
# ['nasionalreadpelatih', 'chelsea', 'mauricio', 'pochettino', 'menitipkan', 'pesan', 'nicolas', 'jackson', 'tampil', 'impresif', 'menghadapi', 'tottenham', 'hotspur', 'chelsea', 'membungkan', 'tottenham', 'skor', '41', 'pekan', 'ke11', 'premier', 'league', 'kasta', 'tertinggi', 'liga', 'inggris', '20232024', 'laga', 'tottenham', 'vs', 'chelsea', 'jadwal', 'liga', 'inggris', 'stadion', 'tottenham', 'hotspur', 'selasa', '7112023', 'drama', 'laga', 'tottenham', 'vs', 'chelsea', 'menyusul', 'insiden', 'kartu', 'merah', 'menimpa', 'pemain', 'spurs', 'cristian', 'romero', 'destiny', 'udogie', 'samping', 'nicolas', 'jackson', 'muncul', 'bintang', 'membukukan', 'hattrick', 'gol', 'chelsea', 'menit', 'ke75', '904', '907', 'nicolas', 'jackson', 'raihan', 'gol', 'torehan', 'membangun', 'kepercayaan', 'pemain', 'klub', 'spanyol', 'villarreal', 'pikir', 'bagus', 'membangun', 'kepercayaan', 'jackson', 'mauricio', 'pochettino', 'dikutip', 'metro', 'striker', 'muda', 'klub', 'chelsea', 'imbuhnya', 'baca', 'drama', 'var', 'tottenham', 'vs', 'chelsea', 'tambahan', '21', 'menit', 'pelatih', 'berkebangsaan', 'argentina', 'berharap', 'nicolas', 'jackson', 'berkembang', 'mengemas', 'hattrick', 'pasalnya', 'pochettino', 'jackson', 'menorehkan', 'gol', 'chelsea', 'menderita']
# ['kompascom', 'pemain', 'panama', 'u17', 'martin', 'krug', 'terkesima', 'kualitas', 'stadion', 'gelora', 'tomo', 'surabayanstadion', 'berkapasitas', '44200', 'penonton', 'venue', 'babak', 'penyisihan', 'grup', 'a', 'piala', 'dunia', 'u17', '2023', 'indonesia', 'jumat', '10112023', 'ininmenurut', 'stadion', 'terletak', 'daerah', 'benowo', 'memiliki', 'fasilitas', 'lengkap', 'megah', 'pemandangan', 'memanjakan', 'matanitu', 'membuatnya', 'antusias', 'bertanding', 'stadion', 'gelora', 'tomo', 'penuh', 'penonton', 'merasakan', 'tampil', 'disaksikan', 'orang', 'kalinyanbaca', 'piala', 'dunia', 'u17', 'permintaan', 'khusus', 'garuda', 'harap', 'riuh', 'suporter', 'takuti', 'lawannmungkin', 'tanggal', '10', 'november', 'orang', 'kali', 'bermain', 'sepak', 'bola', 'orang', 'memenuhi', 'stadion', 'pemain', 'bernama', 'lengkap', 'martin', 'wilhelm', 'krug', 'tersebutnya', 'mengadakan', 'pre', 'mundial', 'kualifikasi', 'piala', 'dunia', 'u17', 'guatemala', 'orang', 'lingkungan', 'berbeda', 'katanyantimnas', 'panama', 'laga', 'perdananya', 'melawan', 'maroko', 'lawan', 'merepotkan', 'kedalaman', 'pemain', 'berkualitasnnamun', 'percaya', 'kualitas', 'kesiapan', 'timnas', 'panama', 'martin', 'krug', 'tim', 'perlawanan', 'bagusnbaca', 'piala', 'dunia', 'u17', '2023', 'bertiket', 'harap', 'masuk', 'gbtnnamun', 'pikir', 'pertandingan', 'bagus', 'pemain', 'muda', 'klub', 'kasta', 'liga', 'spanyol', 'levantenkepercayaan', 'persiapan', 'berjalan', 'lancar', 'tim', 'kuat', 'harinya', 'menemukan', 'kendala', 'berartinsecara', 'tim', 'kualitas', 'memenangi', 'pertandingannkompascomsuci', 'rahayu', 'diselasela', 'latihan', 'jelang', 'piala', 'dunia', 'u17', '2023', 'indonesia', 'pemain', 'timnas', 'panama', 'u17', 'martin', 'krug', 'wawancara', 'jurnalis', 'd', 'stadion', 'gelora', 'tomo', 'surabaya', 'jawa', 'timur', 'selasa', '7112023', 'sorenitu', 'bagus', 'memiliki', 'energi', 'pikir', 'pertandingan', 'katanyantimnas', 'panama', 'u17', 'tim', 'berasal', 'concacaf', 'amerika', 'kali', 'ketiga', 'tampil', 'piala', 'dunia', 'u17', '2011', '2013ntim', 'modal', 'berhasil', 'mengamankan', 'tiket', 'piala', 'dunia', 'u17', '2023', 'berhasil', 'semifinalis', 'concacaf', 'u17', '2023', 'lalunlangkah', 'terhenti', 'kalah', '05', 'meksiko', 'u17', 'juara']

# %% [markdown]
# Kemudian dibersihkan datanya kita dapat menjadikan data tersebut menjadi vectorization dengan 50 feature dan frekuensinya 3
#
# dan kita melakukan train test slpit 0.4  karena minimnya dataset

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.svm import SVC
tfidf_vectorizer = TfidfVectorizer(max_features=50, min_df=3)
documents = [' '.join(tokens) for tokens in array_of_tokenized]


tfidf_matrix = tfidf_vectorizer.fit_transform(documents)
print(tfidf_matrix)

from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(tfidf_matrix, dataset['Label'], test_size=0.4, random_state=122)
# Out:
#   (0, 4)	0.30442495712972306
#   (0, 11)	0.6088499142594461
#   (0, 28)	0.27065560176294645
#   (0, 14)	0.6088499142594461
#   (0, 30)	0.30442495712972306
#   (1, 36)	0.2363469155086841
#   (1, 24)	0.18870802894256158
#   (1, 27)	0.2363469155086841
#   (1, 17)	0.21012934433808766
#   (1, 8)	0.21012934433808766
#   (1, 0)	0.2363469155086841
#   (1, 21)	0.1705965648399034
#   (1, 9)	0.5661240868276848
#   (1, 10)	0.2821382847528781
#   (1, 22)	0.2363469155086841
#   (1, 2)	0.2363469155086841
#   (1, 35)	0.2363469155086841
#   (1, 37)	0.2363469155086841
#   (1, 13)	0.2363469155086841
#   (2, 16)	0.3186077388961825
#   (2, 33)	0.15930386944809125
#   (2, 29)	0.14163255554066148
#   (2, 3)	0.15930386944809125
#   (2, 5)	0.7081627777033073
#   (2, 18)	0.15930386944809125
#   :	:
#   (8, 3)	0.12548980901813128
#   (8, 5)	0.22313886545409886
#   (8, 18)	0.12548980901813128
#   (8, 8)	0.11156943272704943
#   (8, 0)	0.12548980901813128
#   (8, 21)	0.18115853380047287
#   (8, 9)	0.3005869714172758
#   (8, 10)	0.07490150526005258
#   (8, 4)	0.25097961803626256
#   (9, 7)	0.12072476842624233
#   (9, 12)	0.12072476842624233
#   (9, 6)	0.24144953685248466
#   (9, 31)	0.10733297018146055
#   (9, 34)	0.4828990737049693
#   (9, 1)	0.5366648509073026
#   (9, 15)	0.12072476842624233
#   (9, 18)	0.24144953685248466
#   (9, 24)	0.3855642972150624
#   (9, 0)	0.12072476842624233
#   (9, 21)	0.0871398331570485
#   (9, 9)	0.1927821486075312
#   (9, 11)	0.12072476842624233
#   (9, 28)	0.10733297018146055
#   (9, 14)	0.12072476842624233
#   (9, 30)	0.24144953685248466

# %% [markdown]
# Saat sudah dipecah menjadi train test. maka kita langsung ambil model SVM dari library sklearn.svm dan langsung train, test dan prediksi hasil tersebut

# %%
from sklearn.metrics import accuracy_score
from sklearn.svm import SVC
svm_classifier = SVC(kernel='linear')
svm_classifier.fit(X_train, y_train)
y_pred = svm_classifier.predict(X_test)

accuracy = accuracy_score(y_test, y_pred)
print("Accuracy:", accuracy)
# Out:
# Accuracy: 0.75

# %%
print(y_test)
print("=======")
print(y_pred)
# Out:
# 7      Politik
# 8      Politik
# 9         Bola
# 1    Kesehatan
# Name: Label, dtype: object
# =======
# ['Politik' 'Politik' 'Bola' 'Politik']

# %% [markdown]
# #Random Forest
# Untuk model Random Forest, sama juga akan ambil dari sklearn.ensemble
# dan lakukan hal yang sama yaitu train model dan test hasil model tersebut untuk mengecek akurasinya

# %%
#Random Forest
from sklearn.ensemble import RandomForestClassifier
rf = RandomForestClassifier()
rf.fit(X_train, y_train)
y_pred = rf.predict(X_test)
accuracy = accuracy_score(y_test, y_pred)
print("Accuracy:", accuracy)
# Out:
# Accuracy: 0.5

# %% [markdown]
# #1. SVM ini lebih kompatible atau bekerja lebih baik pada dataset yang non-linear kompleks. makanya RandomForest memiliki akurasi yang lebih kecil darip ada SVM
# #2. Dataset yang dimiliki cukup sedikit sehingga sulit untuk mengidentifikasinya
